# %% [markdown]
# # Rekordbox Duplicate Track Removal-Inator

# %% [markdown]
# Given a Rekordbox collection XML file, this code finds duplicate (Artist, Track Name, Album) entries and identifies which duplicates to remove.
#
# Where one or more duplicate entries have cuepoints, this program scores each entry according to the number of cuepoints and their type. This score is designed to weigh loops more than basic cues.
#
# The goal is to clean up my Rekordbox collection, which, for reasons I don't know, is full of duplicates.
#
# The following code was tested on XML output from Rekordbox version 6.8.3.

# %% [markdown]
# ## Load useful libraries

# %%
import xmltodict

# %% [markdown]
# The following is part of the toolkit I'm writing to deal with Rekordbox issues:

# %%
from rekordbox_interface import *

# %% [markdown]
# ## User settings

# %%
xml_file = '../xml.xml'

# %% [markdown]
# ## Load the XML exported from rekordbox and parse into a Python dictionary

# %%
with open(xml_file, 'r') as file:
    xml_as_string = file.read().replace('\n', '')

# %%
dict_rekordbox_content = xmltodict.parse(xml_as_string)

# %%
class_all_tracks = rkb_all_tracks(dict_rekordbox_content)

# %% [markdown]
# ## Analyze duplicate entries in Rekordbox database to decide which of a duplicate pair to keep

# %% [markdown]
# #### Identify the duplicates

# %%
def identify_duplicate_track_entries(tracks):

    df_agg_to_find_duplicates = (
        tracks
        .df_track_info
        .groupby(['Name', 'Artist', 'Album'])
        .agg('count')
        ['TrackID']
        .reset_index()
        .rename(columns={'TrackID' : 'count'})
    )

    df_duplicates = (
        pd.merge(
            df_agg_to_find_duplicates[df_agg_to_find_duplicates['count'] > 1],
            tracks.df_track_info,
            on = ['Name', 'Artist', 'Album'],
            how = 'left',
        )[['Artist', 'Name', 'Album', 'TrackID']]
        .sort_values(by = ['Artist', 'Name', 'Album', 'TrackID'])
        .copy()
    )
    
    return(df_duplicates)

# %%
df_duplicates = identify_duplicate_track_entries(class_all_tracks)

df_duplicates
# Out:
#              Artist                              Name  \
# 194                                              HORN
# 195                                              HORN
# 530      2 Indabush                          The Lick
# 531      2 Indabush                          The Lick
# 44             8.02            Believe (Extended Mix)
# ..              ...                               ...
# 450        Waldhaus        Set Me Free (Original Mix)
# 253  Zsa Zsa Deluxe  Inside of Me (Cs Johansen Remix)
# 252  Zsa Zsa Deluxe  Inside of Me (Cs Johansen Remix)
# 112           kWASP   Distorted People (Original Mix)
# 113           kWASP   Distorted People (Original Mix)
#
#                                                 Album    TrackID
# 194                                                     94849455
# 195                                                    244339207
# 530                            Club Flys 3-Late Night   39578582
# 531                            Club Flys 3-Late Night  232360351
# 44                                            Believe   46698218
# ..                                                ...        ...
# 450                                       Set Me Free  169662044
# 253  Best of Rave Classics (Remix Edition) [Explicit]  250715880
# 252  Best of Rave Classics (Remix Edition) [Explicit]  256757927
# 112                                  Distorted People  132769205
# 113                                  Distorted People  213835313
#
# [622 rows x 4 columns]

# %% [markdown]
# #### Where duplicate tracks are found, select which one to keep
#
# By first deciding which to keep, we avoid any risk in case there are more than two duplicates for a given track:

# %%
def identify_duplicate_tracks_to_keep(df_duplicates, tracks):

    #
    # compute the components necessary for computing a score for each duplicated track
    #
    df_score = (
        pd.merge(
            df_duplicates,
            tracks.df_all_cue_positions,
            on = ['TrackID'],
            how = 'left',
        )
        .fillna({'Type' : 0.})
        .rename(columns = {'Name_x' : 'track_name', 'Name_y' : 'cue_name'})
        .groupby(['Artist', 'track_name', 'Album', 'TrackID'])
        ['Type']
        .agg(['sum', 'count'])
        .reset_index()
    )

    #
    # compute score
    # 
    # then convert resulting score to integer (I think this will produce more stable joins
    # than floating values for score would)
    #
    # for some reason, this works better with "int(x)" rather than "np.int64(...)"
    #
    df_score['score'] = (df_score['sum'] + df_score['count']) / 2
    df_score['score'] = [int(x) for x in df_score['score']]

    #
    # determine which of a given duplicate track carries the highest score
    # (we want to keep these)
    #
    df_max_score = (
        df_score
        .groupby(['Artist', 'track_name', 'Album'])
        ['score']
        .agg('max')
        .reset_index()
    )

    #
    # convert resulting score to integer (I think this will produce more stable joins
    # than floating values for score would)
    #
    # for some reason, this works better with "int(x)" rather than "np.int64(...)"
    #
    df_max_score['score'] = [int(x) for x in df_max_score['score']]

    #
    # join to retrieve TrackID
    #
    df_tracks_score = (
        pd.merge(
            df_max_score,
            df_score[['Artist', 'track_name', 'Album', 'score', 'TrackID']],
            on = ['Artist', 'track_name', 'Album', 'score'],
            how = 'left'
        )
    )

    #
    # if there are multiple rows for a given ('Artist', 'track_name', 'Album', 'score')
    # having the same max score, we keep the one with the lowest 'TrackID', assuming
    # it was the earliest loaded
    #
    df_earliest = (
        df_tracks_score
        .groupby(['Artist', 'track_name', 'Album'])
        ['TrackID']
        .agg('min')
        .reset_index()
    )
    
    df_earliest['keep'] = True
    
    return df_earliest

# %%
df_earliest = identify_duplicate_tracks_to_keep(df_duplicates, class_all_tracks)

df_earliest[['Artist', 'track_name', 'Album', 'TrackID']]
# Out:
#              Artist                               track_name  \
# 0                                                       HORN
# 1        2 Indabush                                 The Lick
# 2              8.02                   Believe (Extended Mix)
# 3            Aannaa  OINGO BOINGO_WEIRD SCIENCE_AANNAA REMIX
# 4     Alannah Myles                             Black Velvet
# ..              ...                                      ...
# 306          Vareso              Come With Me (Extended Mix)
# 307   Vincent Caira                This Clean (Original Mix)
# 308        Waldhaus               Set Me Free (Original Mix)
# 309  Zsa Zsa Deluxe         Inside of Me (Cs Johansen Remix)
# 310           kWASP          Distorted People (Original Mix)
#
#                                                 Album    TrackID
# 0                                                       94849455
# 1                              Club Flys 3-Late Night   39578582
# 2                                             Believe   46698218
# 3                                              Lockup    3607748
# 4                                    Striptease Music   10843849
# ..                                                ...        ...
# 306                                      Come With Me  132818211
# 307                                        This Clean   19126218
# 308                                       Set Me Free   87882711
# 309  Best of Rave Classics (Remix Edition) [Explicit]  256757927
# 310                                  Distorted People  132769205
#
# [311 rows x 4 columns]

# %% [markdown]
# #### Figure out the tracks to remove
#
# Because we select only one to keep (in case there exists more than one duplicate), we can now robustly identify which tracks to remove:

# %%
def figure_out_which_tracks_to_remove(df_duplicates, df_earliest):
    df_all_duplicated_tracks = (
        pd.merge(
            df_duplicates,
            df_earliest[['TrackID', 'keep']],
            on = 'TrackID',
            how = 'left',
        )
        .fillna({'keep' : False})
    )
    df_false = df_all_duplicated_tracks[~df_all_duplicated_tracks['keep']]
    
    return sorted(list(df_false['TrackID'].values))

# %% [markdown]
# ## We'll use these results later to reconstruct the XML without the duplicates
#
# I'll write that code later, after an EXTENSIVE backup of my current track library.

# %%
df_tracks_to_remove = figure_out_which_tracks_to_remove(df_duplicates, df_earliest)

df_tracks_to_remove
# Out:
# [3429062,
#  12701254,
#  16811311,
#  25261442,
#  29388175,
#  30655891,
#  30891963,
#  30925493,
#  32384172,
#  34368550,
#  39723179,
#  40017280,
#  40508267,
#  43228081,
#  43484650,
#  44525925,
#  49431154,
#  49520596,
#  54907449,
#  54954678,
#  57261431,
#  58079814,
#  58298479,
#  60052045,
#  60392567,
#  61083825,
#  61411077,
#  63575365,
#  64927631,
#  66065039,
#  66340879,
#  68414878,
#  69675834,
#  69738312,
#  70851859,
#  72505140,
#  73357303,
#  74132723,
#  75376485,
#  76200870,
#  77774510,
#  78997152,
#  83447217,
#  85134900,
#  85252860,
#  85590321,
#  86117985,
#  87518576,
#  89418452,
#  90597190,
#  90758377,
#  91290961,
#  92682568,
#  92907093,
#  92971575,
#  93751960,
#  93973548,
#  94359416,
#  94693555,
#  94748269,
#  96063061,
#  99726780,
#  101292769,
#  103617769,
#  103695715,
#  104338978,
#  104776060,
#  107104587,
#  107117042,
#  107811460,
#  108085663,
#  110819995,
#  112053744,
#  112167172,
#  113057562,
#  114815813,
#  114930045,
#  115925832,
#  116723211,
#  117955149,
#  118576448,
#  120872668,
#  121825358,
#  122281636,
#  122401079,
#  122422886,
#  122528659,
#  123686181,
#  124552918,
#  125780411,
#  125969939,
#  126686455,
#  127773826,
#  129081299,
#  131525089,
#  132562544,
#  133566834,
#  134946734,
#  135181059,
#  135570531,
#  136273455,
#  136386514,
#  136504401,
#  137849069,
#  138403751,
#  139427900,
#  139788249,
#  142118705,
#  143109091,
#  144442616,
#  146234322,
#  146365364,
#  146445152,
#  146701734,
#  146903498,
#  147707338,
#  148483320,
#  148512880,
#  148790666,
#  150322288,
#  150406104,
#  153040955,
#  153247402,
#  154102869,
#  154260217,
#  157343372,
#  158023735,
#  158324416,
#  158475004,
#  158741056,
#  158936011,
#  160000674,
#  160432431,
#  160538447,
#  161186385,
#  162354571,
#  162759532,
#  163624257,
#  163754067,
#  164180850,
#  164370292,
#  165829951,
#  166032378,
#  166230002,
#  167831137,
#  169662044,
#  169699540,
#  169918835,
#  170499395,
#  170940309,
#  172204051,
#  172638006,
#  172763327,
#  174040991,
#  176015662,
#  176101978,
#  177396653,
#  177474675,
#  177885028,
#  178756498,
#  179263973,
#  179438541,
#  181340590,
#  183146542,
#  183379742,
#  183762820,
#  183868968,
#  187115634,
#  187126717,
#  187663114,
#  189251070,
#  189606078,
#  190380185,
#  190667015,
#  192402664,
#  192531641,
#  192533182,
#  192982677,
#  193162306,
#  194477805,
#  194512623,
#  195227894,
#  195333419,
#  195338308,
#  195563536,
#  195751493,
#  197902590,
#  198111865,
#  198695019,
#  201726121,
#  203273385,
#  203284348,
#  205576033,
#  206164866,
#  206264336,
#  207159632,
#  207249556,
#  208107269,
#  208846562,
#  209350481,
#  213835313,
#  214286100,
#  214331253,
#  214445827,
#  214751756,
#  214775725,
#  215176992,
#  215448107,
#  217100338,
#  217619280,
#  218171876,
#  219491602,
#  220276443,
#  220565545,
#  220755068,
#  221222749,
#  221777826,
#  222471394,
#  222960218,
#  223651114,
#  223897107,
#  224099835,
#  224337475,
#  224912759,
#  226263762,
#  226794598,
#  226952863,
#  227311214,
#  228031040,
#  228611788,
#  229093001,
#  230888805,
#  231370447,
#  232360351,
#  235144817,
#  235420928,
#  236253201,
#  237225374,
#  237431657,
#  237457831,
#  237764815,
#  237839208,
#  238049515,
#  238142902,
#  238639248,
#  238756162,
#  239615949,
#  239706936,
#  239758152,
#  240557620,
#  241793118,
#  241836492,
#  242290190,
#  242593845,
#  242758977,
#  243389056,
#  244339207,
#  244573479,
#  245276599,
#  247422042,
#  247491545,
#  247624769,
#  247793762,
#  247850335,
#  247949743,
#  247989473,
#  248539715,
#  248813811,
#  248960981,
#  250715880,
#  250837639,
#  250996334,
#  252146830,
#  252238181,
#  253094832,
#  253433972,
#  253640213,
#  253994395,
#  254272643,
#  254385186,
#  254953533,
#  255024933,
#  256394027,
#  257818356,
#  258041898,
#  258101765,
#  258222422,
#  258394923,
#  258844418,
#  258913783,
#  258943360,
#  258996609,
#  259007490,
#  259897580,
#  260743687,
#  261915592,
#  262483080,
#  262573124,
#  262801326,
#  263161524,
#  263352388,
#  264142580,
#  264651814,
#  264911224,
#  265304350,
#  265511548,
#  265607655,
#  266831226,
#  267424623,
#  267597103,
#  267710388]
